# %%
import pandas as pd
import numpy as np
import sys
import os
from tqdm import tqdm
import joblib

notebook_dir = os.getcwd() 
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
sys.path.append(project_root)

from config.config import DB_PATH, PREDICTOR_MODEL_PATH

from Database.database_manager import DatabaseManager
from Fight_Predictor.Fight_Context import Fight_Context

# %%
with DatabaseManager(DB_PATH) as db:
    red_fighter = db.get_fighter_by_id(2096)
    blue_fighter = db.get_fighter_by_id(3694)

# %%
context = Fight_Context(red_fighter, blue_fighter, '2025-09-28', winner_id = None)
final_features = context.create_features()

red_fighter_id = context.red_fighter.id

# %%
X = final_features
X.head()
# Out:
#    experiance_diff  win_proportion_diff  loss_proportion_diff  height_diff_cm  \
# 0               27            -0.082888              0.082888           20.32
#
#    reach_diff_cm  age_diff  prime_score_diff   elo_diff  quality_score_diff  \
# 0          30.48  6.253251         -0.767997  97.254104          182.825849
#
#    form_diff  ...  tertiary_1_Conventional Frame (Sideways)  \
# 0   5.780638  ...                                         0
#
#    tertiary_1_Conventional Frame (Southpaw)  \
# 0                                         0
#
#    tertiary_1_Conventional Frame (Switch)  tertiary_1_Newcomer  \
# 0                                       0                    0
#
#    tertiary_2_Conventional Frame (Open Stance)  \
# 0                                            0
#
#    tertiary_2_Conventional Frame (Orthodox)  \
# 0                                         0
#
#    tertiary_2_Conventional Frame (Sideways)  \
# 0                                         0
#
# ...

# %%
bushy_model = joblib.load(PREDICTOR_MODEL_PATH)

# %%
prediction = bushy_model.predict(X.values)

# %%
print(prediction)
# Out:
# [1]

# %%
print (red_fighter_id)
# Out:
# 2096
