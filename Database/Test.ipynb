# %%
import sys
import os

notebook_dir = os.getcwd() 
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
sys.path.append(project_root)

from config.config import DB_PATH
from Data_Scraper import upcoming_scraper
from Database.database_manager import DatabaseManager

# %%
with DatabaseManager(DB_PATH) as db:
    fights = db.get_fight_by_id(2899)
    print(fights)
# Out:
# {'fight_id': 1, 'red_fighter_id': 2899, 'blue_fighter_id': 3774, 'winner_id': None, 'event_date': '2021-03-13', 'win_method': 'CNC', 'final_round': 2, 'red_knockdowns': 0, 'red_sig_strikes': 19, 'red_takedowns': 0, 'blue_knockdowns': 0, 'blue_sig_strikes': 8, 'blue_takedowns': 0, 'is_completed': 1, 'event_url': 'http://ufcstats.com/event-details/8c90c1563972e44d', 'red_sub_attempts': 0, 'blue_sub_attempts': 0, 'final_time_seconds': 18, 'red_fighter_elo_before': 1626.7592075618343, 'blue_fighter_elo_before': 1630.9689477056852, 'red_fighter_elo_after': 1626.8958615214724, 'blue_fighter_elo_after': 1630.8334304233667}
